# %% [markdown]
# <a href="https://colab.research.google.com/github/NAMITHASS/UNSUPERVISIED_LEARNING/blob/main/Xgboost_for_house_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
import xgboost as xgb

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df_test=pd.read_csv('https://raw.githubusercontent.com/ezioauditore-tech/AI/main/datasets/house-prices-advanced-regression-techniques/test.csv')
df=pd.read_csv('https://raw.githubusercontent.com/ezioauditore-tech/AI/main/datasets/house-prices-advanced-regression-techniques/train.csv')#train data

# %%
df_test.describe()
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000  ...
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704  ...
# std       1.113740    30.390071     21.130467   177.625900   455.268042  ...
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#mode=most occuring value
rev_null=['LotFrontage','Alley','MasVnrType','MasVnrArea','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Electrical','FireplaceQu','GarageType','GarageYrBlt','GarageFinish','GarageQual','GarageCond','PoolQC','Fence','MiscFeature']
df[rev_null]=df[rev_null].replace({np.nan:df['LotFrontage'].mode(),
                                   np.nan:df['Alley'].mode(),
                                   np.nan:df['MasVnrType'].mode(),
                                   np.nan:df['MasVnrArea'].mode(),
                                   np.nan:df['BsmtQual'].mode(),
                                   np.nan:df['BsmtCond'].mode(),
                                   np.nan:df['BsmtExposure'].mode(),
                                   np.nan:df['BsmtFinType1'].mode(),
                                   np.nan:df['BsmtFinType2'].mode(),
                                   np.nan:df['Electrical'].mode(),
                                   np.nan:df['FireplaceQu'].mode(),
                                   np.nan:df['GarageType'].mode(),
                                   np.nan:df['GarageYrBlt'].mode(),
                                   np.nan:df['GarageFinish'].mode(),
                                   np.nan:df['GarageQual'].mode(),
                                   np.nan:df['GarageCond'].mode(),
                                   np.nan:df['PoolQC'].mode(),
                                   np.nan:df['Fence'].mode(),
                                   np.nan:df['MiscFeature'].mode(),
                                   np.nan:df['BsmtQual'].mode(),
                                   np.nan:df['BsmtQual'].mode(),
                                   np.nan:df['BsmtQual'].mode(),
                                   np.nan:df['BsmtQual'].mode(),
                                   np.nan:df['BsmtQual'].mode(),})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.dropna(subset=['MasVnrArea'], inplace=True)
df.dropna(subset=['GarageYrBlt'], inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      250
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
en=LabelEncoder()
df['LotFrontage']=en.fit_transform(df.LotFrontage)
df['Alley']=en.fit_transform(df.Alley)
df['MasVnrType']=en.fit_transform(df.MasVnrType)
df['BsmtQual']=en.fit_transform(df.BsmtQual)
df['BsmtCond']=en.fit_transform(df.BsmtCond)
df['BsmtExposure']=en.fit_transform(df.BsmtExposure)
df['BsmtFinType1']=en.fit_transform(df.BsmtFinType1)
df['BsmtFinType2']=en.fit_transform(df.BsmtFinType2)
df['Electrical']=en.fit_transform(df.Electrical)
df['FireplaceQu']=en.fit_transform(df.FireplaceQu)
df['GarageType']=en.fit_transform(df.GarageType)
df['GarageFinish']=en.fit_transform(df.GarageFinish)
df['GarageQual']=en.fit_transform(df.GarageQual)
df['GarageCond']=en.fit_transform(df.GarageCond)
df['PoolQC']=en.fit_transform(df.PoolQC)
df['Fence']=en.fit_transform(df.Fence)
df['MiscFeature']=en.fit_transform(df.MiscFeature)
